# %%
import os
import sys
import json
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scikit_posthocs as sp

from tensorflow import keras
from itertools import combinations
from scipy.stats import shapiro, f_oneway, kruskal
from sklearn.metrics import classification_report, confusion_matrix
from statsmodels.stats.multicomp import MultiComparison

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(os.path.join(module_path))

from functions.plotting import plot_bars, plot_bar_from_dict

WIDTH = 150
HEIGHT = 150

# %%
data_dir = os.path.join(
    '..',
    '..',
    '..',
    'data1',
    'images_original_inception_resnet_v2_150x150_categorized')
centered_data_dir = os.path.join(
    '..',
    '..',
    '..',
    'data1',
    'images_original_inception_resnet_v2_150x150_categorized_and_normalized')
test_data_dir = os.path.join(data_dir, 'validation')
centered_test_data_dir = os.path.join(centered_data_dir, 'validation')
test_ds = keras.utils.image_dataset_from_directory(
    directory=test_data_dir,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(HEIGHT, WIDTH),
    shuffle=False)
centered_test_ds = keras.utils.image_dataset_from_directory(
    directory=centered_test_data_dir,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(HEIGHT, WIDTH),
    shuffle=False)
# Out:
# Found 2000 files belonging to 7 classes.
# Found 2000 files belonging to 7 classes.

# %%
ROOT_NAME = 'xception'
models_dir = os.path.join(
    '..',
    '..',
    'models',
    'data1')
model_file_names = list(filter(lambda model_file_name: ROOT_NAME in model_file_name, os.listdir(models_dir)))

# %%
def get_accuracies_and_losses(models: list[str]) -> (dict[str, float], dict[str, float]):
    accuracies = {}
    losses = {}

    for model_name in models:
        if 'samplewise_centering' in model_name:
            evaluation_dataset = centered_test_ds
        else:
            evaluation_dataset = test_ds

        model_path = os.path.join(models_dir, model_name)
        model = keras.models.load_model(model_path)
        loss, _, _, accuracy, _, _ = model.evaluate(evaluation_dataset)
        accuracies[model_name] = accuracy
        losses[model_name] = loss

    return accuracies, losses

# %%
accuracies_file = os.path.join('..', '..', 'histories', f'{ROOT_NAME}_accuracies.json')
losses_file = os.path.join('..', '..', 'histories', f'{ROOT_NAME}_losses.json')

# %%
if not os.path.exists(accuracies_file):
    accuracies, losses = get_accuracies_and_losses(model_file_names)

    with open(accuracies_file, 'w') as json_file:
        json.dump(accuracies, json_file, indent=4)
    with open(losses_file, 'w') as json_file:
        json.dump(losses, json_file, indent=4)
# Out:
# 63/63 [==============================] - 8s 37ms/step - loss: 0.5753 - categorical cross entropy: 0.5753 - mean squared error: 0.0402 - accuracy: 0.8015 - auc: 0.9266 - prc: 0.6631
# 63/63 [==============================] - 4s 37ms/step - loss: 0.5359 - categorical cross entropy: 0.5359 - mean squared error: 0.0366 - accuracy: 0.8280 - auc: 0.9446 - prc: 0.7533
# 63/63 [==============================] - 4s 37ms/step - loss: 0.5456 - categorical cross entropy: 0.5456 - mean squared error: 0.0375 - accuracy: 0.8155 - auc: 0.9501 - prc: 0.7404
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5563 - categorical cross entropy: 0.5563 - mean squared error: 0.0400 - accuracy: 0.8060 - auc: 0.9370 - prc: 0.6977
# 63/63 [==============================] - 5s 38ms/step - loss: 0.5528 - categorical cross entropy: 0.5528 - mean squared error: 0.0386 - accuracy: 0.8150 - auc: 0.9308 - prc: 0.7352
# 63/63 [==============================] - 4s 37ms/step - loss: 0.5033 - categorical cross entropy: 0.5033 - mean squared error: 0.0362 - accuracy: 0.8165 - auc: 0.9452 - prc: 0.7391
# 63/63 [==============================] - 5s 38ms/step - loss: 0.5489 - categorical cross entropy: 0.5489 - mean squared error: 0.0374 - accuracy: 0.8225 - auc: 0.9410 - prc: 0.7559
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5090 - categorical cross entropy: 0.5090 - mean squared error: 0.0364 - accuracy: 0.8235 - auc: 0.9402 - prc: 0.7264
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5238 - categorical cross entropy: 0.5238 - mean squared error: 0.0366 - accuracy: 0.8205 - auc: 0.9374 - prc: 0.7511
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5633 - categorical cross entropy: 0.5633 - mean squared error: 0.0384 - accuracy: 0.8155 - auc: 0.9331 - prc: 0.6949
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5274 - categorical cross entropy: 0.5274 - mean squared error: 0.0372 - accuracy: 0.8100 - auc: 0.9439 - prc: 0.7412
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5420 - categorical cross entropy: 0.5420 - mean squared error: 0.0387 - accuracy: 0.8105 - auc: 0.9463 - prc: 0.7171
# 63/63 [==============================] - 4s 38ms/step - loss: 0.5146 - categorical cross entropy: 0.5146 - mean squared error: 0.0361 - accuracy: 0.8295 - auc: 0.9420 - prc: 0.7516

# %%
with open(accuracies_file, 'r') as accuracies_file_handle:
    accuracies = json.load(accuracies_file_handle)
with open(losses_file, 'r') as losses_file_handle:
    losses = json.load(losses_file_handle)

# %%
root = os.path.join('..', '..', 'plots', 'testing')
accuracies_pdf_path = os.path.join(root, f'{ROOT_NAME}_accuracies.pdf')

plot_bar_from_dict(accuracies, 'Model Accuracies', 'Name', 'Accuracy', accuracies_pdf_path)

# %%
losses_pdf_path = os.path.join(root, f'{ROOT_NAME}_losses.pdf')

plot_bar_from_dict(losses, 'Model Losses', 'Name', 'Accuracy', losses_pdf_path)

# %%
model_categories = set(map(lambda name: '_'.join(name.split('_')[:-2]), model_file_names))
grouped_models = {key: list(filter(lambda name: name.startswith(key), model_file_names)) for key in model_categories}
keyed_accuracies = {key: [] for key in grouped_models}
keyed_losses = {key: [] for key in grouped_models}


def categorize_numbers(for_dict: dict[str, list[float]], numbers_dict: dict[str, float]) -> None:
    for group, value in for_dict.items():
        vals = [
            value for key, value in numbers_dict.items()
            if key.startswith(group)]

        value.extend(vals)


categorize_numbers(keyed_accuracies, accuracies)
categorize_numbers(keyed_losses, losses)

# %%
ALPHA = .05
anova_testable_groups = []
kruskal_walis_testable_groups = []


def assign_models_to_groups(models: list[float], col: str) -> None:
    _, p_value = shapiro(models)

    if p_value >= ALPHA:
        anova_testable_groups.append(col)
    else:
        kruskal_walis_testable_groups.append(col)


keys = list(keyed_accuracies.keys())

for idx in range(len(keys)):
    assign_models_to_groups(keyed_accuracies[keys[idx]], keys[idx])

# %%
kruskal_values = []

for col in kruskal_walis_testable_groups:
    kruskal_values.append(keyed_accuracies[col])

h_stat_kruskal, p_value_kruskal = kruskal(*kruskal_values)

print(f'Kruskal-Wallis p-value: {p_value_kruskal}')
# Out:
# Kruskal-Wallis p-value: 0.8360008326269326

# %% [markdown]
# Kruskal-Wallis p-value is much bigger than the assumed 0.05 ALPHA value, therefore null hypothesis cannot be rejected. It seems that on average whatever method of improvement we choose, it's approximately as good as the other ones. Let's pick the best one and see the confusion matrix.

# %%
model_name = ''
best_acc = 0

for key, value in accuracies.items():
    if value > best_acc:
        model_name = key
        best_acc = value

model_path = os.path.join(models_dir, model_name)
chosen_model = keras.models.load_model(model_path)
no_adjustment_prediction = chosen_model.predict(test_ds)
# Out:
# 63/63 [==============================] - 3s 36ms/step

# %%
def get_ys(predictions):
    y_pred_labels = np.argmax(predictions, axis=1)
    y_test = []

    for _, labels in test_ds:
        y_test.extend(np.argmax(labels.numpy(), axis=-1))

    y_test = np.array(y_test)

    return y_test, y_pred_labels

# %%
def show_report(y_test, y_pred) -> None:
    report = classification_report(y_test, y_pred, target_names=test_ds.class_names, zero_division=0)
    print(report)

    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(10,10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_ds.class_names, yticklabels=test_ds.class_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

# %%
y_test, y_pred_labels = get_ys(no_adjustment_prediction)

show_report(y_test, y_pred_labels)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.55      0.61        65
#          bcc       0.69      0.60      0.64       102
#          bkl       0.72      0.66      0.69       219
#           df       0.78      0.61      0.68        23
#          mel       0.64      0.48      0.55       222
#           nv       0.89      0.96      0.92      1341
#         vasc       0.76      0.93      0.84        28
#
#     accuracy                           0.84      2000
#    macro avg       0.74      0.68      0.70      2000
# weighted avg       0.82      0.84      0.83      2000

# %%
pred_accuracy = np.sum(y_pred_labels == y_test) / len(y_test)

print(f"Accuracy of predictions: {pred_accuracy * 100:.2f}%")
# Out:
# Accuracy of predictions: 81.95%

# %% [markdown]
# Now let's also consider the other model that was not present in the kruskal_walis_testable_groups

# %%
model_name = ''
best_acc = 0

for key, value in accuracies.items():
    if anova_testable_groups[0] in key and value > best_acc:
        model_name = key
        best_acc = value

model_path = os.path.join(models_dir, model_name)
chosen_model = keras.models.load_model(model_path)
anova_model_prediction = chosen_model.predict(test_ds)
# Out:
# 63/63 [==============================] - 3s 37ms/step

# %%
y_test, y_pred_labels = get_ys(anova_model_prediction)

show_report(y_test, y_pred_labels)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.64      0.49      0.56        65
#          bcc       0.55      0.81      0.65       102
#          bkl       0.60      0.69      0.64       219
#           df       0.55      0.74      0.63        23
#          mel       0.69      0.43      0.53       222
#           nv       0.91      0.92      0.92      1341
#         vasc       1.00      0.79      0.88        28
#
#     accuracy                           0.82      2000
#    macro avg       0.71      0.70      0.69      2000
# weighted avg       0.82      0.82      0.82      2000

# %%
pred_accuracy = np.sum(y_pred_labels == y_test) / len(y_test)

print(f"Accuracy of predictions: {pred_accuracy * 100:.2f}%")
# Out:
# Accuracy of predictions: 81.95%
