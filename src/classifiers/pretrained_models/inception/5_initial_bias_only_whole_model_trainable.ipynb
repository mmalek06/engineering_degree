# %%
import os
import sys
import numpy as np

from tensorflow import keras

module_path = os.path.abspath(os.path.join('..', '..', '..'))

if module_path not in sys.path:
    sys.path.append(os.path.join(module_path))

from functions.augmentation import get_augmentation_layers
from functions.model_running import get_run_number, run_model
from models.inception_resnet_v2_models import get_basic_model

# %%
BATCH_SIZE = 64
WIDTH = 150
HEIGHT = 150
ROOT = os.path.join('..', '..', '..', '..')
DS_NAME = 'data1'
DATA_DIR = os.path.join(
    ROOT,
    '..',
    DS_NAME,
    'images_original_inception_resnet_v2_150x150_categorized')
MODEL_NAME_BASE = 'inception_5_initial_bias_only_whole_model_trainable'

# %%
METRICS = [
    keras.metrics.CategoricalCrossentropy(name='categorical cross entropy'),
    keras.metrics.MeanSquaredError(name='mean squared error'),
    keras.metrics.CategoricalAccuracy(name='accuracy'),
    keras.metrics.AUC(name='auc', multi_label=True),
    keras.metrics.AUC(name='prc', curve='PR', multi_label=True)
]

# %%
train_ds_dir = os.path.join(DATA_DIR, 'training')
class_dirs = [
    os.path.join(train_ds_dir, class_dir)
    for class_dir in os.listdir(train_ds_dir)
    if os.path.isdir(os.path.join(train_ds_dir, class_dir))]
class_counts = [len(os.listdir(class_dir)) for class_dir in class_dirs]
total_samples = np.sum(class_counts)
initial_biases = np.log(class_counts / (total_samples - class_counts))

# %%
_, history = run_model(
    ROOT,
    HEIGHT,
    WIDTH,
    DATA_DIR,
    DS_NAME,
    MODEL_NAME_BASE,
    lambda num_classes:
        lambda: get_basic_model(
            HEIGHT,
            WIDTH,
            num_classes,
            metrics=METRICS,
            biases=keras.initializers.Constant(initial_biases)),
    get_augmentation_layers,
    batch_size=BATCH_SIZE,
    stopping_patience=20)
# Out:
# Found 8015 files belonging to 7 classes.
# Found 2000 files belonging to 7 classes.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Epoch 1/100
# 126/126 [==============================] - ETA: 0s - loss: 2.1313 - categorical cross entropy: 2.1313 - mean squared error: 0.0651 - accuracy: 0.6769 - auc: 0.7216 - prc: 0.2391
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_1\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_1\assets
# 126/126 [==============================] - 133s 892ms/step - loss: 2.1313 - categorical cross entropy: 2.1313 - mean squared error: 0.0651 - accuracy: 0.6769 - auc: 0.7216 - prc: 0.2391 - val_loss: 0.9885 - val_categorical cross entropy: 0.9885 - val_mean squared error: 0.0646 - val_accuracy: 0.6705 - val_auc: 0.7431 - val_prc: 0.2554 - lr: 0.0010
# Epoch 2/100
# 126/126 [==============================] - ETA: 0s - loss: 0.8757 - categorical cross entropy: 0.8757 - mean squared error: 0.0550 - accuracy: 0.7163 - auc: 0.8558 - prc: 0.3595
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_2\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_2\assets
# 126/126 [==============================] - 110s 876ms/step - loss: 0.8757 - categorical cross entropy: 0.8757 - mean squared error: 0.0550 - accuracy: 0.7163 - auc: 0.8558 - prc: 0.3595 - val_loss: 0.8691 - val_categorical cross entropy: 0.8691 - val_mean squared error: 0.0594 - val_accuracy: 0.6860 - val_auc: 0.8917 - val_prc: 0.4765 - lr: 0.0010
# Epoch 3/100
# 126/126 [==============================] - ETA: 0s - loss: 0.7447 - categorical cross entropy: 0.7447 - mean squared error: 0.0504 - accuracy: 0.7440 - auc: 0.8897 - prc: 0.4566
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_3\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_3\assets
# 126/126 [==============================] - 113s 894ms/step - loss: 0.7447 - categorical cross entropy: 0.7447 - mean squared error: 0.0504 - accuracy: 0.7440 - auc: 0.8897 - prc: 0.4566 - val_loss: 0.6445 - val_categorical cross entropy: 0.6445 - val_mean squared error: 0.0450 - val_accuracy: 0.7735 - val_auc: 0.9055 - val_prc: 0.5658 - lr: 0.0010
# Epoch 4/100
# 126/126 [==============================] - 58s 455ms/step - loss: 0.6652 - categorical cross entropy: 0.6652 - mean squared error: 0.0471 - accuracy: 0.7614 - auc: 0.9112 - prc: 0.5088 - val_loss: 0.9534 - val_categorical cross entropy: 0.9534 - val_mean squared error: 0.0465 - val_accuracy: 0.7610 - val_auc: 0.9120 - val_prc: 0.5653 - lr: 0.0010
# Epoch 5/100
# 126/126 [==============================] - ETA: 0s - loss: 0.6371 - categorical cross entropy: 0.6371 - mean squared error: 0.0454 - accuracy: 0.7709 - auc: 0.9197 - prc: 0.5509
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_5\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_5\assets
# 126/126 [==============================] - 114s 905ms/step - loss: 0.6371 - categorical cross entropy: 0.6371 - mean squared error: 0.0454 - accuracy: 0.7709 - auc: 0.9197 - prc: 0.5509 - val_loss: 0.6181 - val_categorical cross entropy: 0.6181 - val_mean squared error: 0.0443 - val_accuracy: 0.7710 - val_auc: 0.9166 - val_prc: 0.5904 - lr: 0.0010
# Epoch 6/100
# 126/126 [==============================] - 59s 462ms/step - loss: 0.6058 - categorical cross entropy: 0.6058 - mean squared error: 0.0435 - accuracy: 0.7778 - auc: 0.9288 - prc: 0.5897 - val_loss: 0.6335 - val_categorical cross entropy: 0.6335 - val_mean squared error: 0.0446 - val_accuracy: 0.7750 - val_auc: 0.9249 - val_prc: 0.6165 - lr: 0.0010
# Epoch 7/100
# 126/126 [==============================] - 59s 467ms/step - loss: 0.6068 - categorical cross entropy: 0.6068 - mean squared error: 0.0433 - accuracy: 0.7840 - auc: 0.9300 - prc: 0.6103 - val_loss: 0.6506 - val_categorical cross entropy: 0.6506 - val_mean squared error: 0.0445 - val_accuracy: 0.7735 - val_auc: 0.9085 - val_prc: 0.6233 - lr: 0.0010
# Epoch 8/100
# 126/126 [==============================] - 58s 459ms/step - loss: 0.5652 - categorical cross entropy: 0.5652 - mean squared error: 0.0414 - accuracy: 0.7925 - auc: 0.9381 - prc: 0.6445 - val_loss: 0.6319 - val_categorical cross entropy: 0.6319 - val_mean squared error: 0.0446 - val_accuracy: 0.7705 - val_auc: 0.9247 - val_prc: 0.6368 - lr: 0.0010
# Epoch 9/100
# 126/126 [==============================] - ETA: 0s - loss: 0.5424 - categorical cross entropy: 0.5424 - mean squared error: 0.0397 - accuracy: 0.8012 - auc: 0.9430 - prc: 0.6624
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_9\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_9\assets
# 126/126 [==============================] - 120s 957ms/step - loss: 0.5424 - categorical cross entropy: 0.5424 - mean squared error: 0.0397 - accuracy: 0.8012 - auc: 0.9430 - prc: 0.6624 - val_loss: 0.6089 - val_categorical cross entropy: 0.6089 - val_mean squared error: 0.0438 - val_accuracy: 0.7795 - val_auc: 0.9286 - val_prc: 0.6438 - lr: 0.0010
# Epoch 10/100
# 126/126 [==============================] - 60s 471ms/step - loss: 0.5315 - categorical cross entropy: 0.5315 - mean squared error: 0.0389 - accuracy: 0.8067 - auc: 0.9411 - prc: 0.6848 - val_loss: 293.6243 - val_categorical cross entropy: 293.6243 - val_mean squared error: 0.2249 - val_accuracy: 0.1920 - val_auc: 0.5286 - val_prc: 0.2253 - lr: 0.0010
# Epoch 11/100
# 126/126 [==============================] - 59s 472ms/step - loss: 0.5438 - categorical cross entropy: 0.5438 - mean squared error: 0.0396 - accuracy: 0.8000 - auc: 0.9412 - prc: 0.6831 - val_loss: 0.6877 - val_categorical cross entropy: 0.6877 - val_mean squared error: 0.0480 - val_accuracy: 0.7715 - val_auc: 0.9291 - val_prc: 0.6826 - lr: 0.0010
# Epoch 12/100
# 126/126 [==============================] - 59s 470ms/step - loss: 0.5256 - categorical cross entropy: 0.5256 - mean squared error: 0.0385 - accuracy: 0.8106 - auc: 0.9465 - prc: 0.7007 - val_loss: 0.6127 - val_categorical cross entropy: 0.6127 - val_mean squared error: 0.0420 - val_accuracy: 0.7885 - val_auc: 0.9281 - val_prc: 0.6682 - lr: 0.0010
# Epoch 13/100
# 126/126 [==============================] - ETA: 0s - loss: 0.5045 - categorical cross entropy: 0.5045 - mean squared error: 0.0370 - accuracy: 0.8173 - auc: 0.9514 - prc: 0.7075
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_13\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_13\assets
# 126/126 [==============================] - 122s 969ms/step - loss: 0.5045 - categorical cross entropy: 0.5045 - mean squared error: 0.0370 - accuracy: 0.8173 - auc: 0.9514 - prc: 0.7075 - val_loss: 0.5767 - val_categorical cross entropy: 0.5767 - val_mean squared error: 0.0429 - val_accuracy: 0.7795 - val_auc: 0.9402 - val_prc: 0.7068 - lr: 0.0010
# Epoch 14/100
# 126/126 [==============================] - 62s 486ms/step - loss: 0.4949 - categorical cross entropy: 0.4949 - mean squared error: 0.0365 - accuracy: 0.8215 - auc: 0.9515 - prc: 0.7224 - val_loss: 0.5826 - val_categorical cross entropy: 0.5826 - val_mean squared error: 0.0427 - val_accuracy: 0.7830 - val_auc: 0.9310 - val_prc: 0.7046 - lr: 0.0010
# Epoch 15/100
# 126/126 [==============================] - ETA: 0s - loss: 0.4848 - categorical cross entropy: 0.4848 - mean squared error: 0.0358 - accuracy: 0.8242 - auc: 0.9553 - prc: 0.7377
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_15\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_5_initial_bias_only_whole_model_trainable_20_15\assets
# 126/126 [==============================] - 123s 981ms/step - loss: 0.4848 - categorical cross entropy: 0.4848 - mean squared error: 0.0358 - accuracy: 0.8242 - auc: 0.9553 - prc: 0.7377 - val_loss: 0.5379 - val_categorical cross entropy: 0.5379 - val_mean squared error: 0.0392 - val_accuracy: 0.8080 - val_auc: 0.9422 - val_prc: 0.6910 - lr: 0.0010
# Epoch 16/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.4697 - categorical cross entropy: 0.4697 - mean squared error: 0.0349 - accuracy: 0.8261 - auc: 0.9592 - prc: 0.7602 - val_loss: 245.3058 - val_categorical cross entropy: 245.3058 - val_mean squared error: 0.0815 - val_accuracy: 0.6620 - val_auc: 0.8290 - val_prc: 0.5039 - lr: 0.0010
# Epoch 17/100
# 126/126 [==============================] - 64s 506ms/step - loss: 0.5204 - categorical cross entropy: 0.5204 - mean squared error: 0.0384 - accuracy: 0.8070 - auc: 0.9527 - prc: 0.7095 - val_loss: 1.9288 - val_categorical cross entropy: 1.9288 - val_mean squared error: 0.0557 - val_accuracy: 0.7360 - val_auc: 0.9010 - val_prc: 0.5889 - lr: 0.0010
# Epoch 18/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.4898 - categorical cross entropy: 0.4898 - mean squared error: 0.0361 - accuracy: 0.8197 - auc: 0.9536 - prc: 0.7277 - val_loss: 0.6836 - val_categorical cross entropy: 0.6836 - val_mean squared error: 0.0472 - val_accuracy: 0.7690 - val_auc: 0.9012 - val_prc: 0.6375 - lr: 0.0010
# Epoch 19/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.5822 - categorical cross entropy: 0.5822 - mean squared error: 0.0420 - accuracy: 0.7914 - auc: 0.9357 - prc: 0.6508 - val_loss: 443.0941 - val_categorical cross entropy: 443.0941 - val_mean squared error: 0.1706 - val_accuracy: 0.3595 - val_auc: 0.5848 - val_prc: 0.2568 - lr: 0.0010
# Epoch 20/100
# 126/126 [==============================] - 64s 511ms/step - loss: 0.5686 - categorical cross entropy: 0.5686 - mean squared error: 0.0413 - accuracy: 0.7908 - auc: 0.9368 - prc: 0.6575 - val_loss: 0.6779 - val_categorical cross entropy: 0.6779 - val_mean squared error: 0.0459 - val_accuracy: 0.7700 - val_auc: 0.9101 - val_prc: 0.6048 - lr: 0.0010
# Epoch 21/100
# 126/126 [==============================] - 65s 513ms/step - loss: 0.5264 - categorical cross entropy: 0.5264 - mean squared error: 0.0388 - accuracy: 0.8072 - auc: 0.9495 - prc: 0.7018 - val_loss: 0.5722 - val_categorical cross entropy: 0.5722 - val_mean squared error: 0.0399 - val_accuracy: 0.8095 - val_auc: 0.9329 - val_prc: 0.6813 - lr: 0.0010
# Epoch 22/100
# 126/126 [==============================] - 65s 513ms/step - loss: 0.4887 - categorical cross entropy: 0.4887 - mean squared error: 0.0363 - accuracy: 0.8197 - auc: 0.9567 - prc: 0.7323 - val_loss: 0.8743 - val_categorical cross entropy: 0.8743 - val_mean squared error: 0.0563 - val_accuracy: 0.7245 - val_auc: 0.8665 - val_prc: 0.4691 - lr: 0.0010
# Epoch 23/100
# 126/126 [==============================] - 64s 510ms/step - loss: 0.5276 - categorical cross entropy: 0.5276 - mean squared error: 0.0386 - accuracy: 0.8101 - auc: 0.9475 - prc: 0.7002 - val_loss: 0.8011 - val_categorical cross entropy: 0.8011 - val_mean squared error: 0.0490 - val_accuracy: 0.7675 - val_auc: 0.9245 - val_prc: 0.6312 - lr: 0.0010
# Epoch 24/100
# 126/126 [==============================] - 64s 509ms/step - loss: 0.4962 - categorical cross entropy: 0.4962 - mean squared error: 0.0369 - accuracy: 0.8171 - auc: 0.9535 - prc: 0.7280 - val_loss: 4.0954 - val_categorical cross entropy: 4.0954 - val_mean squared error: 0.0660 - val_accuracy: 0.6920 - val_auc: 0.9227 - val_prc: 0.6442 - lr: 0.0010
# Epoch 25/100
# 126/126 [==============================] - ETA: 0s - loss: 0.4838 - categorical cross entropy: 0.4838 - mean squared error: 0.0359 - accuracy: 0.8222 - auc: 0.9568 - prc: 0.7590
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 126/126 [==============================] - 64s 508ms/step - loss: 0.4838 - categorical cross entropy: 0.4838 - mean squared error: 0.0359 - accuracy: 0.8222 - auc: 0.9568 - prc: 0.7590 - val_loss: 3.4559 - val_categorical cross entropy: 3.4559 - val_mean squared error: 0.0722 - val_accuracy: 0.6865 - val_auc: 0.8740 - val_prc: 0.6008 - lr: 0.0010
# Epoch 26/100
# 126/126 [==============================] - 64s 511ms/step - loss: 0.4609 - categorical cross entropy: 0.4609 - mean squared error: 0.0348 - accuracy: 0.8256 - auc: 0.9575 - prc: 0.7653 - val_loss: 0.5620 - val_categorical cross entropy: 0.5620 - val_mean squared error: 0.0401 - val_accuracy: 0.7935 - val_auc: 0.9339 - val_prc: 0.6861 - lr: 9.5000e-04
# Epoch 27/100
# 126/126 [==============================] - 64s 511ms/step - loss: 0.4393 - categorical cross entropy: 0.4393 - mean squared error: 0.0332 - accuracy: 0.8311 - auc: 0.9642 - prc: 0.7766 - val_loss: 0.7091 - val_categorical cross entropy: 0.7091 - val_mean squared error: 0.0477 - val_accuracy: 0.7620 - val_auc: 0.9301 - val_prc: 0.6763 - lr: 9.5000e-04
# Epoch 28/100
# 126/126 [==============================] - 64s 511ms/step - loss: 0.4629 - categorical cross entropy: 0.4629 - mean squared error: 0.0347 - accuracy: 0.8301 - auc: 0.9594 - prc: 0.7696 - val_loss: 0.7600 - val_categorical cross entropy: 0.7600 - val_mean squared error: 0.0515 - val_accuracy: 0.7465 - val_auc: 0.9087 - val_prc: 0.6124 - lr: 9.5000e-04
# Epoch 29/100
# 126/126 [==============================] - 64s 508ms/step - loss: 0.4642 - categorical cross entropy: 0.4642 - mean squared error: 0.0348 - accuracy: 0.8266 - auc: 0.9589 - prc: 0.7598 - val_loss: 0.6954 - val_categorical cross entropy: 0.6954 - val_mean squared error: 0.0490 - val_accuracy: 0.7615 - val_auc: 0.9155 - val_prc: 0.6498 - lr: 9.5000e-04
# Epoch 30/100
# 126/126 [==============================] - 64s 508ms/step - loss: 0.4985 - categorical cross entropy: 0.4985 - mean squared error: 0.0371 - accuracy: 0.8173 - auc: 0.9525 - prc: 0.7345 - val_loss: 4.6268 - val_categorical cross entropy: 4.6268 - val_mean squared error: 0.0652 - val_accuracy: 0.7145 - val_auc: 0.7437 - val_prc: 0.4110 - lr: 9.5000e-04
# Epoch 31/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.5901 - categorical cross entropy: 0.5901 - mean squared error: 0.0426 - accuracy: 0.7886 - auc: 0.9288 - prc: 0.6461 - val_loss: 26.2835 - val_categorical cross entropy: 26.2835 - val_mean squared error: 0.1767 - val_accuracy: 0.2840 - val_auc: 0.6798 - val_prc: 0.2776 - lr: 9.5000e-04
# Epoch 32/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.5997 - categorical cross entropy: 0.5997 - mean squared error: 0.0438 - accuracy: 0.7809 - auc: 0.9312 - prc: 0.6232 - val_loss: 10.9470 - val_categorical cross entropy: 10.9470 - val_mean squared error: 0.0943 - val_accuracy: 0.5945 - val_auc: 0.8548 - val_prc: 0.5639 - lr: 9.5000e-04
# Epoch 33/100
# 126/126 [==============================] - 64s 507ms/step - loss: 0.5323 - categorical cross entropy: 0.5323 - mean squared error: 0.0394 - accuracy: 0.8045 - auc: 0.9483 - prc: 0.6944 - val_loss: 0.6666 - val_categorical cross entropy: 0.6666 - val_mean squared error: 0.0481 - val_accuracy: 0.7625 - val_auc: 0.9286 - val_prc: 0.6493 - lr: 9.5000e-04
# Epoch 34/100
# 126/126 [==============================] - 64s 506ms/step - loss: 0.5169 - categorical cross entropy: 0.5169 - mean squared error: 0.0384 - accuracy: 0.8061 - auc: 0.9502 - prc: 0.7210 - val_loss: 0.8393 - val_categorical cross entropy: 0.8393 - val_mean squared error: 0.0569 - val_accuracy: 0.7200 - val_auc: 0.9018 - val_prc: 0.5323 - lr: 9.5000e-04
# Epoch 35/100
# 126/126 [==============================] - ETA: 0s - loss: 0.5289 - categorical cross entropy: 0.5289 - mean squared error: 0.0390 - accuracy: 0.8069 - auc: 0.9485 - prc: 0.7019
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 126/126 [==============================] - 64s 506ms/step - loss: 0.5289 - categorical cross entropy: 0.5289 - mean squared error: 0.0390 - accuracy: 0.8069 - auc: 0.9485 - prc: 0.7019 - val_loss: 1.2450 - val_categorical cross entropy: 1.2450 - val_mean squared error: 0.0536 - val_accuracy: 0.7465 - val_auc: 0.9188 - val_prc: 0.5858 - lr: 9.5000e-04
