# %%
import os
import sys
import numpy as np

from tensorflow import keras

module_path = os.path.abspath(os.path.join('..', '..', '..'))

if module_path not in sys.path:
    sys.path.append(os.path.join(module_path))

from functions.augmentation import get_augmentation_layers
from functions.model_running import get_run_number, run_model
from models.efficientnet_v2 import get_v2m_model

# %%
WIDTH = 150
HEIGHT = 150
ROOT = os.path.join('..', '..', '..', '..')
DS_NAME = 'data1'
DATA_DIR = os.path.join(
    ROOT,
    '..',
    DS_NAME,
    'images_original_inception_resnet_v2_150x150_categorized')
MODEL_NAME_BASE = 'efficientnet_v2_4_v2m_initial_bias_only'

# %%
train_ds_dir = os.path.join(DATA_DIR, 'training')
class_dirs = [
    os.path.join(train_ds_dir, class_dir)
    for class_dir in os.listdir(train_ds_dir)
    if os.path.isdir(os.path.join(train_ds_dir, class_dir))]
class_counts = [len(os.listdir(class_dir)) for class_dir in class_dirs]
total_samples = np.sum(class_counts)
initial_biases = np.log(class_counts / (total_samples - class_counts))

# %%
METRICS = [
    keras.metrics.CategoricalCrossentropy(name='categorical cross entropy'),
    keras.metrics.MeanSquaredError(name='mean squared error'),
    keras.metrics.CategoricalAccuracy(name='accuracy'),
    keras.metrics.AUC(name='auc', multi_label=True),
    keras.metrics.AUC(name='prc', curve='PR', multi_label=True)
]

# %%
run_model(
    ROOT,
    HEIGHT,
    WIDTH,
    DATA_DIR,
    DS_NAME,
    MODEL_NAME_BASE,
    lambda num_classes:
        lambda: get_v2m_model(
            HEIGHT,
            WIDTH,
            num_classes,
            metrics=METRICS,
            biases=keras.initializers.Constant(initial_biases)),
    get_augmentation_layers)
# Out:
# Found 8015 files belonging to 7 classes.
# Found 2000 files belonging to 7 classes.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Epoch 1/100
# 251/251 [==============================] - ETA: 0s - loss: 1.5045 - categorical cross entropy: 1.5045 - mean squared error: 0.0648 - accuracy: 0.6836 - auc: 0.7922 - prc: 0.2695
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 245). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_1\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_1\assets
# 251/251 [==============================] - 235s 823ms/step - loss: 1.5045 - categorical cross entropy: 1.5045 - mean squared error: 0.0648 - accuracy: 0.6836 - auc: 0.7922 - prc: 0.2695 - val_loss: 0.7212 - val_categorical cross entropy: 0.7212 - val_mean squared error: 0.0496 - val_accuracy: 0.7510 - val_auc: 0.8856 - val_prc: 0.4687 - lr: 0.0010
# Epoch 2/100
# 251/251 [==============================] - 94s 372ms/step - loss: 0.7668 - categorical cross entropy: 0.7668 - mean squared error: 0.0527 - accuracy: 0.7276 - auc: 0.8717 - prc: 0.4169 - val_loss: 0.7253 - val_categorical cross entropy: 0.7253 - val_mean squared error: 0.0480 - val_accuracy: 0.7640 - val_auc: 0.8881 - val_prc: 0.5345 - lr: 0.0010
# Epoch 3/100
# 251/251 [==============================] - 94s 373ms/step - loss: 0.7687 - categorical cross entropy: 0.7687 - mean squared error: 0.0519 - accuracy: 0.7347 - auc: 0.8742 - prc: 0.4180 - val_loss: 0.8184 - val_categorical cross entropy: 0.8184 - val_mean squared error: 0.0544 - val_accuracy: 0.7210 - val_auc: 0.8986 - val_prc: 0.5194 - lr: 0.0010
# Epoch 4/100
# 251/251 [==============================] - ETA: 0s - loss: 0.7182 - categorical cross entropy: 0.7182 - mean squared error: 0.0497 - accuracy: 0.7401 - auc: 0.8947 - prc: 0.4575
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 245). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_4\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_4\assets
# 251/251 [==============================] - 203s 810ms/step - loss: 0.7182 - categorical cross entropy: 0.7182 - mean squared error: 0.0497 - accuracy: 0.7401 - auc: 0.8947 - prc: 0.4575 - val_loss: 0.6461 - val_categorical cross entropy: 0.6461 - val_mean squared error: 0.0448 - val_accuracy: 0.7710 - val_auc: 0.9197 - val_prc: 0.6034 - lr: 0.0010
# Epoch 5/100
# 251/251 [==============================] - 97s 384ms/step - loss: 0.6837 - categorical cross entropy: 0.6837 - mean squared error: 0.0481 - accuracy: 0.7527 - auc: 0.9040 - prc: 0.5078 - val_loss: 0.7629 - val_categorical cross entropy: 0.7629 - val_mean squared error: 0.0521 - val_accuracy: 0.7250 - val_auc: 0.9011 - val_prc: 0.5882 - lr: 0.0010
# Epoch 6/100
# 251/251 [==============================] - 97s 385ms/step - loss: 0.6672 - categorical cross entropy: 0.6672 - mean squared error: 0.0467 - accuracy: 0.7646 - auc: 0.9135 - prc: 0.5469 - val_loss: 0.7959 - val_categorical cross entropy: 0.7959 - val_mean squared error: 0.0473 - val_accuracy: 0.7770 - val_auc: 0.8600 - val_prc: 0.5644 - lr: 0.0010
# Epoch 7/100
# 251/251 [==============================] - ETA: 0s - loss: 0.6762 - categorical cross entropy: 0.6762 - mean squared error: 0.0467 - accuracy: 0.7633 - auc: 0.9073 - prc: 0.5199
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 245). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_7\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_7\assets
# 251/251 [==============================] - 209s 836ms/step - loss: 0.6762 - categorical cross entropy: 0.6762 - mean squared error: 0.0467 - accuracy: 0.7633 - auc: 0.9073 - prc: 0.5199 - val_loss: 0.6249 - val_categorical cross entropy: 0.6249 - val_mean squared error: 0.0435 - val_accuracy: 0.7840 - val_auc: 0.9223 - val_prc: 0.6251 - lr: 0.0010
# Epoch 8/100
# 251/251 [==============================] - ETA: 0s - loss: 0.6363 - categorical cross entropy: 0.6363 - mean squared error: 0.0448 - accuracy: 0.7780 - auc: 0.9187 - prc: 0.5712
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 245). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_8\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\efficientnet_v2_4_v2m_initial_bias_only_20_8\assets
# 251/251 [==============================] - 214s 853ms/step - loss: 0.6363 - categorical cross entropy: 0.6363 - mean squared error: 0.0448 - accuracy: 0.7780 - auc: 0.9187 - prc: 0.5712 - val_loss: 0.5789 - val_categorical cross entropy: 0.5789 - val_mean squared error: 0.0415 - val_accuracy: 0.7970 - val_auc: 0.9411 - val_prc: 0.6816 - lr: 0.0010
# Epoch 9/100
# 251/251 [==============================] - 101s 403ms/step - loss: 0.6419 - categorical cross entropy: 0.6419 - mean squared error: 0.0449 - accuracy: 0.7745 - auc: 0.9137 - prc: 0.5753 - val_loss: 0.5879 - val_categorical cross entropy: 0.5879 - val_mean squared error: 0.0430 - val_accuracy: 0.7875 - val_auc: 0.9314 - val_prc: 0.6970 - lr: 0.0010
# Epoch 10/100
# 251/251 [==============================] - 101s 404ms/step - loss: 0.6033 - categorical cross entropy: 0.6033 - mean squared error: 0.0427 - accuracy: 0.7876 - auc: 0.9269 - prc: 0.6228 - val_loss: 0.8973 - val_categorical cross entropy: 0.8973 - val_mean squared error: 0.0698 - val_accuracy: 0.6325 - val_auc: 0.9107 - val_prc: 0.6383 - lr: 0.0010
# Epoch 11/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.6075 - categorical cross entropy: 0.6075 - mean squared error: 0.0430 - accuracy: 0.7862 - auc: 0.9266 - prc: 0.6105 - val_loss: 0.6271 - val_categorical cross entropy: 0.6271 - val_mean squared error: 0.0431 - val_accuracy: 0.7820 - val_auc: 0.9186 - val_prc: 0.6469 - lr: 0.0010
# Epoch 12/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.5974 - categorical cross entropy: 0.5974 - mean squared error: 0.0421 - accuracy: 0.7911 - auc: 0.9262 - prc: 0.6240 - val_loss: 0.6858 - val_categorical cross entropy: 0.6858 - val_mean squared error: 0.0426 - val_accuracy: 0.7950 - val_auc: 0.9182 - val_prc: 0.6653 - lr: 0.0010
# Epoch 13/100
# 251/251 [==============================] - 101s 403ms/step - loss: 0.6096 - categorical cross entropy: 0.6096 - mean squared error: 0.0425 - accuracy: 0.7875 - auc: 0.9279 - prc: 0.6192 - val_loss: 0.7625 - val_categorical cross entropy: 0.7625 - val_mean squared error: 0.0516 - val_accuracy: 0.7485 - val_auc: 0.8879 - val_prc: 0.5416 - lr: 0.0010
# Epoch 14/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.6592 - categorical cross entropy: 0.6592 - mean squared error: 0.0454 - accuracy: 0.7735 - auc: 0.9136 - prc: 0.5535 - val_loss: 0.6143 - val_categorical cross entropy: 0.6143 - val_mean squared error: 0.0424 - val_accuracy: 0.7900 - val_auc: 0.9190 - val_prc: 0.6752 - lr: 0.0010
# Epoch 15/100
# 251/251 [==============================] - 102s 406ms/step - loss: 0.7307 - categorical cross entropy: 0.7307 - mean squared error: 0.0498 - accuracy: 0.7492 - auc: 0.8862 - prc: 0.5148 - val_loss: 0.7384 - val_categorical cross entropy: 0.7384 - val_mean squared error: 0.0523 - val_accuracy: 0.7210 - val_auc: 0.9061 - val_prc: 0.5226 - lr: 0.0010
# Epoch 16/100
# 251/251 [==============================] - 101s 404ms/step - loss: 0.7681 - categorical cross entropy: 0.7681 - mean squared error: 0.0524 - accuracy: 0.7349 - auc: 0.8749 - prc: 0.4667 - val_loss: 0.6741 - val_categorical cross entropy: 0.6741 - val_mean squared error: 0.0472 - val_accuracy: 0.7610 - val_auc: 0.9321 - val_prc: 0.6302 - lr: 0.0010
# Epoch 17/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.6740 - categorical cross entropy: 0.6740 - mean squared error: 0.0470 - accuracy: 0.7644 - auc: 0.9056 - prc: 0.5476 - val_loss: 0.7048 - val_categorical cross entropy: 0.7048 - val_mean squared error: 0.0478 - val_accuracy: 0.7720 - val_auc: 0.9024 - val_prc: 0.5828 - lr: 0.0010
# Epoch 18/100
# 251/251 [==============================] - ETA: 0s - loss: 0.7507 - categorical cross entropy: 0.7507 - mean squared error: 0.0501 - accuracy: 0.7487 - auc: 0.8901 - prc: 0.4968
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 251/251 [==============================] - 102s 408ms/step - loss: 0.7507 - categorical cross entropy: 0.7507 - mean squared error: 0.0501 - accuracy: 0.7487 - auc: 0.8901 - prc: 0.4968 - val_loss: 0.7815 - val_categorical cross entropy: 0.7815 - val_mean squared error: 0.0544 - val_accuracy: 0.7295 - val_auc: 0.8831 - val_prc: 0.5778 - lr: 0.0010
# Epoch 19/100
# 251/251 [==============================] - 101s 402ms/step - loss: 0.6478 - categorical cross entropy: 0.6478 - mean squared error: 0.0453 - accuracy: 0.7721 - auc: 0.9130 - prc: 0.5774 - val_loss: 0.7087 - val_categorical cross entropy: 0.7087 - val_mean squared error: 0.0481 - val_accuracy: 0.7570 - val_auc: 0.9201 - val_prc: 0.5912 - lr: 9.5000e-04
# Epoch 20/100
# 251/251 [==============================] - 101s 403ms/step - loss: 0.6091 - categorical cross entropy: 0.6091 - mean squared error: 0.0433 - accuracy: 0.7825 - auc: 0.9224 - prc: 0.6030 - val_loss: 0.6030 - val_categorical cross entropy: 0.6030 - val_mean squared error: 0.0407 - val_accuracy: 0.7995 - val_auc: 0.9178 - val_prc: 0.6239 - lr: 9.5000e-04
# Epoch 21/100
# 251/251 [==============================] - 104s 413ms/step - loss: 0.6151 - categorical cross entropy: 0.6151 - mean squared error: 0.0433 - accuracy: 0.7858 - auc: 0.9242 - prc: 0.6177 - val_loss: 0.6516 - val_categorical cross entropy: 0.6516 - val_mean squared error: 0.0437 - val_accuracy: 0.7800 - val_auc: 0.9116 - val_prc: 0.6431 - lr: 9.5000e-04
# Epoch 22/100
# 251/251 [==============================] - 101s 402ms/step - loss: 0.5897 - categorical cross entropy: 0.5897 - mean squared error: 0.0420 - accuracy: 0.7921 - auc: 0.9338 - prc: 0.6243 - val_loss: 0.6149 - val_categorical cross entropy: 0.6149 - val_mean squared error: 0.0406 - val_accuracy: 0.8035 - val_auc: 0.9233 - val_prc: 0.6586 - lr: 9.5000e-04
# Epoch 23/100
# 251/251 [==============================] - 101s 402ms/step - loss: 0.5905 - categorical cross entropy: 0.5905 - mean squared error: 0.0418 - accuracy: 0.7934 - auc: 0.9293 - prc: 0.6389 - val_loss: 0.7044 - val_categorical cross entropy: 0.7044 - val_mean squared error: 0.0508 - val_accuracy: 0.7475 - val_auc: 0.9168 - val_prc: 0.6708 - lr: 9.5000e-04
# Epoch 24/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.5769 - categorical cross entropy: 0.5769 - mean squared error: 0.0409 - accuracy: 0.8016 - auc: 0.9307 - prc: 0.6392 - val_loss: 0.6883 - val_categorical cross entropy: 0.6883 - val_mean squared error: 0.0442 - val_accuracy: 0.7840 - val_auc: 0.9044 - val_prc: 0.6410 - lr: 9.5000e-04
# Epoch 25/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.5899 - categorical cross entropy: 0.5899 - mean squared error: 0.0415 - accuracy: 0.7966 - auc: 0.9304 - prc: 0.6422 - val_loss: 0.6250 - val_categorical cross entropy: 0.6250 - val_mean squared error: 0.0432 - val_accuracy: 0.7810 - val_auc: 0.9190 - val_prc: 0.6463 - lr: 9.5000e-04
# Epoch 26/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.6556 - categorical cross entropy: 0.6556 - mean squared error: 0.0453 - accuracy: 0.7735 - auc: 0.9083 - prc: 0.5792 - val_loss: 0.6714 - val_categorical cross entropy: 0.6714 - val_mean squared error: 0.0441 - val_accuracy: 0.7885 - val_auc: 0.9041 - val_prc: 0.6255 - lr: 9.5000e-04
# Epoch 27/100
# 251/251 [==============================] - 102s 405ms/step - loss: 0.6235 - categorical cross entropy: 0.6235 - mean squared error: 0.0430 - accuracy: 0.7868 - auc: 0.9248 - prc: 0.6294 - val_loss: 0.6559 - val_categorical cross entropy: 0.6559 - val_mean squared error: 0.0457 - val_accuracy: 0.7580 - val_auc: 0.9163 - val_prc: 0.6306 - lr: 9.5000e-04
# Epoch 28/100
# 251/251 [==============================] - ETA: 0s - loss: 0.6178 - categorical cross entropy: 0.6178 - mean squared error: 0.0434 - accuracy: 0.7835 - auc: 0.9236 - prc: 0.6057
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 251/251 [==============================] - 101s 404ms/step - loss: 0.6178 - categorical cross entropy: 0.6178 - mean squared error: 0.0434 - accuracy: 0.7835 - auc: 0.9236 - prc: 0.6057 - val_loss: 0.7038 - val_categorical cross entropy: 0.7038 - val_mean squared error: 0.0487 - val_accuracy: 0.7645 - val_auc: 0.9113 - val_prc: 0.6244 - lr: 9.5000e-04
# (<keras.engine.functional.Functional at 0x1d530cf0b20>,
#  <keras.callbacks.History at 0x1d530ce2850>)
