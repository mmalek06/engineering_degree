# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..', '..', '..'))

if module_path not in sys.path:
    sys.path.append(os.path.join(module_path))

from functions.augmentation import get_augmentation_layers_with_sample_augmentation
from functions.loading_data import load_dataset, prepare_train_dataset, prepare_valid_dataset
from functions.model_initialization import calculate_initial_biases
from functions.model_running import \
    run_model, \
    get_run_number, \
    increment_run_number,\
    preserve_best_runs
from functions.plotting import plot_single_output_history
from models.inception_resnet_v2_models import get_basic_model

WIDTH = 150
HEIGHT = 150

# %%
data_dir = os.path.join(
    '..',
    '..',
    '..',
    '..',
    '..',
    'data2',
    'images_original_inception_resnet_v2_150x150_categorized_no_test')
train_dataset = load_dataset(HEIGHT, WIDTH, data_dir, 'training')
valid_dataset = load_dataset(HEIGHT, WIDTH, data_dir, 'validation')
# Out:
# Found 21024 files belonging to 8 classes.
# Found 4307 files belonging to 8 classes.

# %%
MODEL_NAME_BASE = 'inception_dealing_with_imbalance_bias_only_1_whole_model_trainable_samplewise_normalization'
num_classes = len(train_dataset.class_names)
run_number = get_run_number(MODEL_NAME_BASE)

# %%
data_augmentation = get_augmentation_layers_with_sample_augmentation()
train_dataset = prepare_train_dataset(train_dataset, data_augmentation)
valid_dataset = prepare_valid_dataset(valid_dataset)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model_name = f'{MODEL_NAME_BASE}_{run_number}'
history = run_model(
    train_dataset,
    valid_dataset,
    lambda: get_basic_model(HEIGHT, WIDTH, num_classes),
    os.path.join('..', '..', '..', '..', 'tmp_models', model_name + '_{epoch}'),
    os.path.join('..', '..', '..', '..', 'tensor_logs', model_name),
    monitor='val_loss',
    reduction_patience=10,
    stopping_patience=20)
# Out:
# Epoch 1/100
# 657/657 [==============================] - ETA: 0s - loss: 1.7036 - accuracy: 0.5002
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_1\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_1\assets
# 657/657 [==============================] - 229s 315ms/step - loss: 1.7036 - accuracy: 0.5002 - val_loss: 94.1360 - val_accuracy: 0.1003 - lr: 0.0010
# Epoch 2/100
# 657/657 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.5227
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_2\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_2\assets
# 657/657 [==============================] - 207s 314ms/step - loss: 1.4021 - accuracy: 0.5227 - val_loss: 3.5646 - val_accuracy: 0.3638 - lr: 0.0010
# Epoch 3/100
# 657/657 [==============================] - ETA: 0s - loss: 1.4054 - accuracy: 0.5252
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_3\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_3\assets
# 657/657 [==============================] - 211s 320ms/step - loss: 1.4054 - accuracy: 0.5252 - val_loss: 1.6134 - val_accuracy: 0.5022 - lr: 0.0010
# Epoch 4/100
# 657/657 [==============================] - 157s 238ms/step - loss: 1.3977 - accuracy: 0.5258 - val_loss: 258.6626 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 5/100
# 657/657 [==============================] - 157s 239ms/step - loss: 1.3548 - accuracy: 0.5413 - val_loss: 1357.2114 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 6/100
# 657/657 [==============================] - 157s 238ms/step - loss: 1.3924 - accuracy: 0.5283 - val_loss: 55.3926 - val_accuracy: 0.5150 - lr: 0.0010
# Epoch 7/100
# 657/657 [==============================] - 157s 239ms/step - loss: 1.4059 - accuracy: 0.5191 - val_loss: 37.1543 - val_accuracy: 0.5099 - lr: 0.0010
# Epoch 8/100
# 657/657 [==============================] - 158s 240ms/step - loss: 1.3792 - accuracy: 0.5265 - val_loss: 757.2817 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 9/100
# 657/657 [==============================] - 157s 239ms/step - loss: 1.3457 - accuracy: 0.5398 - val_loss: 1153.1869 - val_accuracy: 0.5150 - lr: 0.0010
# Epoch
# 657/657 [==============================] - 166s 253ms/step - loss: 1.2875 - accuracy: 0.5556 - val_loss: 10.5622 - val_accuracy: 0.1850 - lr: 0.0010
# Epoch 30/100
# 657/657 [==============================] - 166s 253ms/step - loss: 1.2848 - accuracy: 0.5548 - val_loss: 7.8908 - val_accuracy: 0.1862 - lr: 0.0010
# Epoch 31/100
# 657/657 [==============================] - 166s 252ms/step - loss: 1.2778 - accuracy: 0.5587 - val_loss: 4.9954 - val_accuracy: 0.1792 - lr: 0.0010
# Epoch 32/100
# 657/657 [==============================] - ETA: 0s - loss: 1.3235 - accuracy: 0.5453
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_32\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_32\assets
# 657/657 [==============================] - 226s 344ms/step - loss: 1.3235 - accuracy: 0.5453 - val_loss: 1.4341 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 33/100
# 657/657 [==============================] - ETA: 0s - loss: 1.4224 - accuracy: 0.5133
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 657/657 [==============================] - 170s 258ms/step - loss: 1.4224 - accuracy: 0.5133 - val_loss: 207.3358 - val_accuracy: 0.5092 - lr: 0.0010
# Epoch 34/100
# 657/657 [==============================] - 168s 256ms/step - loss: 1.3802 - accuracy: 0.5244 - val_loss: 13.7172 - val_accuracy: 0.2819 - lr: 9.5000e-04
# Epoch 35/100
# 657/657 [==============================] - 168s 255ms/step - loss: 1.4022 - accuracy: 0.5170 - val_loss: 3.1285 - val_accuracy: 0.1927 - lr: 9.5000e-04
# Epoch 36/100
# 657/657 [==============================] - 167s 254ms/step - loss: 1.3779 - accuracy: 0.5241 - val_loss: 1.4633 - val_accuracy: 0.5134 - lr: 9.5000e-04
# Epoch 37/100
# 657/657 [==============================] - 166s 253ms/step - loss: 1.3610 - accuracy: 0.5286 - val_loss: 1.4495 - val_accuracy: 0.5147 - lr: 9.5000e-04
# Epoch 38/100
# 657/657 [==============================] - 167s 254ms/step - loss: 1.3375 - accuracy: 0.5378 - val_loss: 1.4364 - val_accuracy: 0.5185 - lr: 9.5000e-04
# Epoch 39/100
# 657/657 [==============================] - 169s 257ms/step - loss: 1.3896 - accuracy: 0.5237 - val_loss: 3602.8323 - val_accuracy: 0.1284 - lr: 9.5000e-04
# Epoch 40/100
# 657/657 [==============================] - 167s 254ms/step - loss: 1.3451 - accuracy: 0.5325 - val_loss: 1.4361 - val_accuracy: 0.5147 - lr: 9.5000e-04
# Epoch 41/100
# 657/657 [==============================] - 166s 253ms/step - loss: 1.3341 - accuracy: 0.5366 - val_loss: 33139.7461 - val_accuracy: 0.5152 - lr: 9.5000e-04
# Epoch 42/100
# 657/657 [==============================] - ETA: 0s - loss: 1.3261 - accuracy: 0.5434
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_42\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_42\assets
# 657/657 [==============================] - 226s 344ms/step - loss: 1.3261 - accuracy: 0.5434 - val_loss: 1.4339 - val_accuracy: 0.5152 - lr: 9.5000e-04
# Epoch 43/100
# 657/657 [==============================] - ETA: 0s - loss: 1.3087 - accuracy: 0.5469
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_43\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_1_whole_model_trainable_samplewise_normalization_8_43\assets
# 657/657 [==============================] - 237s 360ms/step - loss: 1.3087 - accuracy: 0.5469 - val_loss: 1.4338 - val_accuracy: 0.5152 - lr: 9.5000e-04

# %%
increment_run_number(MODEL_NAME_BASE)
preserve_best_runs(
    os.path.join('..', '..', '..', '..', 'tmp_models'),
    os.path.join('..', '..', '..', '..', 'models'))
plot_single_output_history(history.history)
