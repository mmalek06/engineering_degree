# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..', '..', '..'))

if module_path not in sys.path:
    sys.path.append(os.path.join(module_path))

from functions.augmentation import get_augmentation_layers
from functions.model_running import run_model
from models.inception_resnet_v2_models import get_model_partly_frozen

# %%
WIDTH = 150
HEIGHT = 150
ROOT = os.path.join('..', '..', '..', '..')
DATA_DIR = os.path.join(
    ROOT,
    '..',
    'data2',
    'images_original_inception_resnet_v2_150x150_categorized_no_test')
MODEL_NAME_BASE = 'inception_ignoring_imbalance_2_only_bottom_half_layers_trainable'

# %%
run_model(
    ROOT,
    HEIGHT,
    WIDTH,
    DATA_DIR,
    MODEL_NAME_BASE,
    lambda num_classes: lambda: get_model_partly_frozen(HEIGHT, WIDTH, num_classes),
    get_augmentation_layers)
# Out:
# Found 21024 files belonging to 8 classes.
# Found 4307 files belonging to 8 classes.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Epoch 1/100
# 657/657 [==============================] - ETA: 0s - loss: 1.7002 - accuracy: 0.5621
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_1\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_1\assets
# 657/657 [==============================] - 219s 303ms/step - loss: 1.7002 - accuracy: 0.5621 - val_loss: 2.6360 - val_accuracy: 0.6002 - lr: 0.0010
# Epoch 2/100
# 657/657 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.6239
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_2\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_2\assets
# 657/657 [==============================] - 198s 302ms/step - loss: 1.0880 - accuracy: 0.6239 - val_loss: 1.1704 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 3/100
# 657/657 [==============================] - ETA: 0s - loss: 1.0347 - accuracy: 0.6387
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_3\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_3\assets
# 657/657 [==============================] - 205s 312ms/step - loss: 1.0347 - accuracy: 0.6387 - val_loss: 0.9497 - val_accuracy: 0.6708 - lr: 0.0010
# Epoch 4/100
# 657/657 [==============================] - ETA: 0s - loss: 1.0221 - accuracy: 0.6467
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_4\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_4\assets
# 657/657 [==============================] - 209s 317ms/step - loss: 1.0221 - accuracy: 0.6467 - val_loss: 0.9104 - val_accuracy: 0.6759 - lr: 0.0010
# Epoch 5/100
# 657/657 [==============================] - 152s 231ms/step - loss: 0.9922 - accuracy: 0.6516 - val_loss: 0.9590 - val_accuracy: 0.6575 - lr: 0.0010
# Epoch 6/100
# 657/657 [==============================] - 153s 232ms/step - loss: 0.9713 - accuracy: 0.6540 - val_loss: 1.0153 - val_accuracy: 0.6633 - lr: 0.0010
# Epoch 7/100
# 657/657 [==============================] - 153s 233ms/step - loss: 0.9711 - accuracy: 0.6592 - val_loss: 0.9337 - val_accuracy: 0.6689 - lr: 0.0010
# Epoch 8/100
# 657/657 [==============================] - ETA: 0s - loss: 0.9566 - accuracy: 0.6627
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_8\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_8\assets
# 657/657 [==============================] - 211s 322ms/step - loss: 0.9566 - accuracy: 0.6627 - val_loss: 0.8976 - val_accuracy: 0.6877 - lr: 0.0010
# Epoch 9/100
# 657/657 [==============================] - 153s 232ms/step - loss: 0.9483 - accuracy: 0.6609 - val_loss: 0.9417 - val_accuracy: 0.6564 - lr: 0.0010
# Epoch 10/100
# 657/657 [==============================] - 154s 234ms/step - loss: 0.9462 - accuracy: 0.6641 - val_loss: 0.9384 - val_accuracy: 0.6675 - lr: 0.0010
# Epoch 11/100
# 657/657 [==============================] - ETA: 0s - loss: 0.9332 - accuracy: 0.6643
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 657/657 [==============================] - 155s 236ms/step - loss: 0.9332 - accuracy: 0.6643 - val_loss: 1.0821 - val_accuracy: 0.6294 - lr: 0.0010
# Epoch 12/100
# 657/657 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.6725
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_12\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_12\assets
# 657/657 [==============================] - 216s 328ms/step - loss: 0.9260 - accuracy: 0.6725 - val_loss: 0.8650 - val_accuracy: 0.6968 - lr: 9.5000e-04
# Epoch 13/100
# 657/657 [==============================] - 161s 245ms/step - loss: 0.9066 - accuracy: 0.6749 - val_loss: 0.8734 - val_accuracy: 0.6884 - lr: 9.5000e-04
# Epoch 14/100
# 657/657 [==============================] - ETA: 0s - loss: 0.9003 - accuracy: 0.6794
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_14\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_14\assets
# 657/657 [==============================] - 217s 330ms/step - loss: 0.9003 - accuracy: 0.6794 - val_loss: 0.8627 - val_accuracy: 0.6961 - lr: 9.5000e-04
# Epoch 15/100
# 657/657 [==============================] - 161s 244ms/step - loss: 0.8805 - accuracy: 0.6842 - val_loss: 0.8730 - val_accuracy: 0.6933 - lr: 9.5000e-04
# Epoch 16/100
# 657/657 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.6858
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_16\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_16\assets
# 657/657 [==============================] - 215s 327ms/step - loss: 0.8806 - accuracy: 0.6858 - val_loss: 0.8585 - val_accuracy: 0.6849 - lr: 9.5000e-04
# Epoch 17/100
# 657/657 [==============================] - ETA: 0s - loss: 0.8668 - accuracy: 0.6907
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_17\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_17\assets
# 657/657 [==============================] - 221s 336ms/step - loss: 0.8668 - accuracy: 0.6907 - val_loss: 0.8511 - val_accuracy: 0.6993 - lr: 9.5000e-04
# Epoch 18/100
# 657/657 [==============================] - ETA: 0s - loss: 0.8556 - accuracy: 0.6937
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_18\assets
# INFO:tensorflow:Assets written to: ..\..\..\..\tmp_models\inception_ignoring_imbalance_2_only_bottom_half_layers_trainable_2_18\assets
# 657/657 [==============================] - 227s 345ms/step - loss: 0.8556 - accuracy: 0.6937 - val_loss: 0.8233 - val_accuracy: 0.7051 - lr: 9.5000e-04
# Epoch 19/100
# 657/657 [==============================] - 160s 243ms/step - loss: 0.8406 - accuracy: 0.6951 - val_loss: 0.9012 - val_accuracy: 0.6787 - lr: 9.5000e-04
# Epoch 20/100
# 657/657 [==============================] - 159s 242ms/step - loss: 0.8255 - accuracy: 0.7041 - val_loss: 0.8236 - val_accuracy: 0.6993 - lr: 9.5000e-04
# Epoch 21/100
# 657/657 [==============================] - ETA: 0s - loss: 0.8306 - accuracy: 0.7021
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 657/657 [==============================] - 158s 241ms/step - loss: 0.8306 - accuracy: 0.7021 - val_loss: 0.8288 - val_accuracy: 0.6961 - lr: 9.5000e-04
